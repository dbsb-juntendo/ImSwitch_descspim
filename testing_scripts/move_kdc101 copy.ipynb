# %%
# connect to the device
from thorlabs_apt_device.devices.kdc101 import KDC101

'''
"rotationStage": {
            "managerName": "KDC101Manager",
            "managerProperties": {
                "port": "COM12",
                "units": "degrees",
                "posConvFac": 1919.641857862339,
                "velConvFac": 42941.66,
                "accConvFac": 14.66
            }
        }
https://www.thorlabs.com/Software/Motion%20Control/APT_Communications_Protocol.pdf

Sample stage S/N 27266343 Port 14 or 15
Camera stage S/N 27266327 Port 14 or 15
Actuator Z8235B  EncCnt per mm  34554.96  Velocity 772981.3692 (mm/s)  Acceleration 263.8443072 (mm/s2)
APT communication protocol page 39

Triggering the stage, information is in the APT communication protocol page 140

widget from abigail
in SetupStatusWidget:
"""Rotation stage"""
self.rotationStageHeader = QtWidgets.QLabel('Rotation stage')
self.rotationStageHeader.setFont(QtGui.QFont('Calibri', 14))
self.rotationStageHeader.setStyleSheet("font-weight: bold")

self.rotationStagePosLabel = QtWidgets.QLabel('Set position (deg) of rotation stage')
self.rotationStagePosEdit = guitools.BetterDoubleSpinBox()
self.rotationStagePosEdit.setDecimals(4)
self.rotationStagePosEdit.setMinimum(-360)
self.rotationStagePosEdit.setMaximum(360)
self.rotationStagePosEdit.setSingleStep(0.01)
self.jogStepSizeLabel = QtWidgets.QLabel('Set jog step size (deg)')
self.jogStepSizeEdit = guitools.BetterDoubleSpinBox()
self.jogStepSizeEdit.setDecimals(4)
self.jogStepSizeEdit.setMaximum(360)
self.jogStepSizeEdit.setSingleStep(0.01)
self.jogPositiveButton = guitools.BetterPushButton('>>')
self.jogNegativeButton = guitools.BetterPushButton('<<')
self.currentPosOfRotationStageLabel = QtWidgets.QLabel('Current position (deg) of rotation stage')
self.currentPosOfRotationStageDisp = QtWidgets.QLabel('')

'''
import time
manager_properties = {
    "port": "COM15",
    "units": "mm",
    "posConvFac": 34554.96,
    "velConvFac": 772981.3692,
    "accConvFac": 263.8443072
}

stage = KDC101(serial_port="COM14")
time.sleep(5)
print(stage.velparams)
# Out:
# {'min_velocity': 0, 'max_velocity': 1700533, 'acceleration': 772981369, 'msg': 'mot_get_velparams', 'msgid': 1045, 'source': 80, 'dest': 1, 'chan_ident': 1}

# %%
dir(stage)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_atexit',
#  '_close_port',
#  '_error_callbacks',
#  '_log',
#  '_loop',
#  '_port',
#  '_process_message',
#  '_run_eventloop',
#  '_schedule_keepalives',
#  '_schedule_reads',
#  '_schedule_updates',
#  '_thread',
#  '_unpacker',
#  '_write',
#  'bays',
#  'channels',
#  'close',
#  'controller',
#  'genmoveparams',
#  'genmoveparams_',
#  'home',
#  'homeparams',
#  'homeparams_',
#  'identify',
#  'invert_direction_logic',
#  'jogparams',
#  'jogparams_',
#  'keepalive_interval',
#  'keepalive_message',
#  'move_absolute',
#  'move_jog',
#  'move_relative',
#  'move_velocity',
#  'read_interval',
#  'register_error_callback',
#  'set_enabled',
#  'set_home_params',
#  'set_jog_params',
#  'set_move_params',
#  'set_velocity_params',
#  'status',
#  'status_',
#  'stop',
#  'swap_limit_switches',
#  'unregister_error_callback',
#  'update_interval',
#  'update_message',
#  'velparams',
#  'velparams_']

# %%
stage.close()

# %%
stage.set_velocity_params(123, 456)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 stage.set_velocity_params(123, 456)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\thorlabs_apt_device\devices\aptdevice_motor.py:421, in APTDevice_Motor.set_velocity_params(self, acceleration, max_velocity, bay, channel)
#     412 """
#     413 Configure the parameters for movement velocity.
#     414
#    (...)
#     418 :param channel: Index (0-based) of controller bay channel to send the command.
#     419 """
#     420 self._log.debug(f"Setting velocity parameters to accel={acceleration}, max={max_velocity} [bay={self.bays[bay]:#x}, channel={self.channels[channel]}].")
# --> 421 self._loop.call_soon_threadsafe(self._write, apt.mot_set_velparams(source=EndPoint.HOST, dest=self.bays[bay], chan_ident=self.channels[channel], min_velocity=0, acceleration=acceleration, max_velocity=max_velocity))
#     422 # Update status with new velocity parameters
#     423 self._loop.call_soon_threadsafe(self._write, apt.mot_req_velparams(source=EndPoint.HOST, dest=self.bays[bay], chan_ident=self.channels[channel]))
#
# AttributeError: 'NoneType' object has no attribute 'call_soon_threadsafe'

# %%
import os
import fnmatch
import re

def search_string_in_files(directory, search_string):
    matches = []
    pattern = re.compile(search_string)

    for root, dirnames, filenames in os.walk(directory):
        for filename in fnmatch.filter(filenames, '*'):
            filepath = os.path.join(root, filename)
            try:
                with open(filepath, 'r', encoding='utf-8', errors='ignore') as file:
                    for line_number, line in enumerate(file, 1):
                        if pattern.search(line):
                            matches.append({
                                'file': filepath,
                                'line_number': line_number,
                                'line': line.strip()
                            })
            except Exception as e:
                print(f"Could not read file {filepath}: {e}")

    return matches

# Example usage
directory_to_search = '../'
string_to_search = 'trigger_source'
results = search_string_in_files(directory_to_search, string_to_search)

for match in results:
    print(f"Found in {match['file']} on line {match['line_number']}: {match['line']}")
# Out:
# Found in ../descspim.json on line 13: "trigger_source": 0
# Found in ../imswitch\imcontrol\model\interfaces\hamamatsu_mock.py on line 98: 'trigger_source': 1,
# Found in ../imswitch\imcontrol\model\interfaces\thorcamscicamera.py on line 283: elif property_name == "trigger_source":
# Found in ../imswitch\imcontrol\model\interfaces\thorcamscicamera.py on line 314: elif property_name == "trigger_source":
# Found in ../imswitch\imcontrol\model\interfaces\thorcamscicamera.py on line 315: property_value = self.trigger_source
# Found in ../imswitch\imcontrol\model\interfaces\thorcamscicamera.py on line 325: def setTriggerSource(self, trigger_source):
# Found in ../imswitch\imcontrol\model\interfaces\thorcamscicamera_max.py on line 238: elif property_name == "trigger_source":         # not sure about this
# Found in ../imswitch\imcontrol\model\interfaces\thorcamscicamera_max.py on line 274: elif property_name == "trigger_source":         # not sure about this
# Found in ../imswitch\imcontrol\model\interfaces\thorcamscicamera_max.py on line 275: property_value = self.trigger_source        # not sure about this
# Found in ../imswitch\imcontrol\model\interfaces\thorcamscicamera_max.py on line 281: def setTriggerSource(self, trigger_source):         # not sure about this
# Found in ../imswitch\imcontrol\model\interfaces\__pycache__\hamamatsu_mock.cpython-310.pyc on line 34: subarray_modetiming_readout_timeinternal_frame_rateinternal_frame_intervaltrigger_sourceZtrigger_moder+r,)rZ_MockHamamatsu__loggerbuffer_index	camera_idcamera_modeldebugframe_xframe_yframe_byteslast_frame_number
# Found in ../imswitch\imcontrol\model\interfaces\__pycache__\hamamatsu_mock.cpython-39.pyc on line 33: subarray_modetiming_readout_timeinternal_frame_rateinternal_frame_intervaltrigger_sourceZtrigger_moder)r*)rZ_MockHamamatsu__loggerbuffer_index	camera_idcamera_modeldebugframe_xframe_yframe_byteslast_frame_number
# Found in ../imswitch\imcontrol\model\interfaces\__pycache__\thorcamscicamera.cpython-310.pyc on line 53: S)Nr*rFr(roi_sizer+trigger_sourceimage_widthrimage_heightr,	Property  does not existF)
# Found in ../imswitch\imcontrol\model\interfaces\__pycache__\thorcamscicamera.cpython-39.pyc on line 37: S|S)Nr)rKr'roi_sizer*trigger_sourcez/setting the triggering here in thorcamscicameraimage_widthrimage_height	Property  does not existF)
# Found in ../imswitch\imcontrol\model\managers\detectors\GXPIPYManager.py on line 55: 'trigger_source': DetectorListParameter(group='Acquisition mode',
# Found in ../imswitch\imcontrol\model\managers\detectors\GXPIPYManager.py on line 106: lambda: self._camera.setPropertyValue('trigger_source', 0)
# Found in ../imswitch\imcontrol\model\managers\detectors\GXPIPYManager.py on line 110: lambda: self._camera.setPropertyValue('trigger_source', 1)
# Found in ../imswitch\imcontrol\model\managers\detectors\GXPIPYManager.py on line 114: lambda: self._camera.setPropertyValue('trigger_source', 2)
# Found in ../imswitch\imcontrol\model\managers\detectors\HamamatsuManager.py on line 130: lambda: self._camera.setPropertyValue('trigger_source', 1)
# Found in ../imswitch\imcontrol\model\managers\detectors\HamamatsuManager.py on line 135: lambda: self._camera.setPropertyValue('trigger_source', 2)
# Found in ../imswitch\imcontrol\model\managers\detectors\HamamatsuManager.py on line 143: lambda: self._camera.setPropertyValue('trigger_source', 2)
# Found in ../imswitch\imcontrol\model\managers\detectors\HamamatsuManager.py on line 170: triggerSource = self._camera.getPropertyValue('trigger_source')
# Found in ../imswitch\imcontrol\model\managers\detectors\ThorCamSciManager.py on line 57: "trigger_source": DetectorNumberParameter(group='Misc',
# Found in ../imswitch\imcontrol\model\managers\detectors\ThorCamSciManager.py on line 93: triggerSource = self._camera.getPropertyValue('trigger_source')
# Found in ../imswitch\imcontrol\model\managers\detectors\ThorCamSciManager.py on line 96: self.setParameter('trigger_source', 0)
# Found in ../imswitch\imcontrol\model\managers\detectors\ThorCamSciManager.py on line 98: self.setParameter('trigger_source', 1)
# Found in ../imswitch\imcontrol\model\managers\detectors\ThorCamSciManager.py on line 100: self.setParameter('trigger_source', 2)
# Found in ../imswitch\imcontrol\model\managers\detectors\ThorCamSciManager.py on line 141: lambda: self._camera.setPropertyValue('trigger_source', 0)
# Found in ../imswitch\imcontrol\model\managers\detectors\ThorCamSciManager.py on line 145: lambda: self._camera.setPropertyValue('trigger_source', 1)
# Found in ../imswitch\imcontrol\model\managers\detectors\ThorCamSciManager.py on line 149: lambda: self._camera.setPropertyValue('trigger_source', 2)
# Found in ../imswitch\imcontrol\model\managers\detectors\ThorCamSciManager_max.py on line 64: "trigger_source": DetectorNumberParameter(group='Misc',
# Found in ../imswitch\imcontrol\model\managers\detectors\ThorCamSciManager_max.py on line 107: triggerSource = self._camera.getPropertyValue('trigger_source')
# Found in ../imswitch\imcontrol\model\managers\detectors\ThorCamSciManager_max.py on line 110: self.setParameter('trigger_source', 0)
# Found in ../imswitch\imcontrol\model\managers\detectors\ThorCamSciManager_max.py on line 112: self.setParameter('trigger_source', 1)
# Found in ../imswitch\imcontrol\model\managers\detectors\ThorCamSciManager_max.py on line 114: self.setParameter('trigger_source', 2)
# Found in ../imswitch\imcontrol\model\managers\detectors\ThorCamSciManager_max.py on line 154: lambda: self._camera.setPropertyValue('trigger_source', 0)
# Found in ../imswitch\imcontrol\model\managers\detectors\ThorCamSciManager_max.py on line 158: lambda: self._camera.setPropertyValue('trigger_source', 1)
# Found in ../imswitch\imcontrol\model\managers\detectors\ThorCamSciManager_max.py on line 162: lambda: self._camera.setPropertyValue('trigger_source', 2)
# Found in ../imswitch\imcontrol\model\managers\detectors\__pycache__\ThorCamSciManager.cpython-310.pyc on line 31: blacklevelZimage_widthZimage_heightCamera pixel sizetrigger_sourceoperation_modeZ
# Found in ../imswitch\imcontrol\model\managers\detectors\__pycache__\ThorCamSciManager.cpython-39.pyc on line 32: blacklevelZimage_widthZimage_heightCamera pixel sizetrigger_sourceZ
# Found in ../imswitch\imcontrol\_test\__init__.py on line 29: "trigger_source": 1,
# Found in ../imswitch\imcontrol\_test\__init__.py on line 200: "trigger_source": 1,
# Found in ../imswitch\imcontrol\_test\unit\__init__.py on line 16: 'trigger_source': 1,
# Found in ../imswitch\imcontrol\_test\unit\__init__.py on line 43: 'trigger_source': 1,
# Found in ../imswitch\imcontrol\_test\unit\__init__.py on line 69: 'trigger_source': 1,
# Found in ../imswitch\_data\user_defaults\imcontrol_setups\example_monalisa.json on line 15: "trigger_source": 1,
# Found in ../imswitch\_data\user_defaults\imcontrol_setups\example_monalisa.json on line 36: "trigger_source": 1,
